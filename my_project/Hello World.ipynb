# %% [markdown]
# # Hello world

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.metrics import mean_squared_error, r2_score

X, y = make_regression(n_samples=100, n_features=1, noise=5, random_state=42, bias=7)
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)
ssr = np.sum((y - y_pred) ** 2)
print(f"ssr: {ssr}")
print(f"Intercept: {model.intercept_}")
print(f"Coefficients: {model.coef_}")
plt.scatter(X, y, label="Data", alpha=0.7, color='black')
plt.plot(X, y_pred, color="grey",label="Regression (OLS) Line")
plt.title("Linear Regression with positive correlation")
plt.xlabel("Independent variables (IVs)")
plt.ylabel("Depdendent variable (DV)")
plt.legend()
plt.show()
# Out:
# ssr: 1951.3562605309742
# Intercept: 7.582557660263486
# Coefficients: [43.08913515]
